# %% [markdown]
# <h1><font size= 10><font color="red"> Welcome to DataRing!</font></font></h1>

# %% [markdown]
# # Heading and diffrent kind<br>
# # Heading
# ## Heading
# ### Heading
# #### Heading
# #### Heading
# ##### Heading
# ##### Heading
#
# <h1> heading with h1 </h1>
# <h2> heading with h2 </h2>
# <h3> heading with h3 </h3>
# <h4> heading with h4 </h4>
#
# # Bold
#
# **make it bold using ***
# <br>
# __make it bold with___
#
# # italic
#
# *make italic using**
# _make italic using__<br>
# ***hi Hope you have understood***
#
# # bullet
# *  first bullet
#     *  second bullet
#         * third bullet
#             * 4th bullet
#
# # indentation
# > first indentation
# >> second indentation
# >>> third indentation
#
# <h1> <font color = "red"> simple points and color </font></h1>
#
# * <font color="blue"> one star will give a simple point </font>
# * <font color ="red"> My favorit color is red </font>
#
#
#
# # highlight<br>
# ` Using the key which is availible just up of the Tab key or you  can search the same just left of key 1 at the left side corner, you may also find it just below of esc key ` <br>
#
# * i wanted to higlight ` this point ` thats all<br>
#
# # number highlight
# ` 1.` Point 1<br>
# ` 2.` Point 1<br>
# ` 3.` Point 3<br>
#
# # adding a link
# https://www.w3schools.io/file/markdown-links/
#
# # adding a picture
# ![python.png.png](attachment:python.png.png)
# ![python.png.png](attachment:python.png.png)
#
# # latex euation
# $ a*b $ <br>
# $(a+b)^2 = 2ab + a^2 + b^2$

# %%
name = input("Enter Your Name")
print("Welcome :", name)

# %%
first_name = input("Enter Your first name")
last_name = input("Enter your Last name")
print('Welcome', first_name, last_name)
# Out:
# Enter Your first nameData
# Enter your Last nameRing
# Welcome Data Ring
